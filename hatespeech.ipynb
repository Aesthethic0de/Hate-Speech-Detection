# %%
import numpy as np 
import pandas as pd

# %%
df_twitter = pd.read_csv('train.csv')

# %%
df_twitter.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
import seaborn as sns
sns.countplot('label',data=df_twitter)
# Out:
# C:\Users\Sunny\.conda\envs\hate\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
df_twitter.shape
# Out:
# (31962, 3)

# %%
df_twitter.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
df_twitter.drop('id',axis=1,inplace=True)

# %%
df_offensive=pd.read_csv("labeled_data.csv")

# %%
df_offensive
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 7 columns]

# %%
df_offensive.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df_offensive.shape
# Out:
# (24783, 7)

# %%
df_offensive.isnull().sum()
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
df_offensive.drop(['Unnamed: 0','count','hate_speech','offensive_language','neither'],axis=1,inplace=True)

# %%
df_offensive.head(10)
# Out:
#    class                                              tweet
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5      1  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
# 6      1  !!!!!!"@__BrighterDays: I can not just sit up ...
# 7      1  !!!!&#8220;@selfiequeenbri: cause I'm tired of...
# 8      1  " &amp; you might not get ya bitch back &amp; ...
# 9      1  " @rhythmixx_ :hobbies include: fighting Maria...

# %%
df_offensive['class'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
sns.countplot('class',data=df_offensive)
# Out:
# C:\Users\Sunny\.conda\envs\hate\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df_offensive[df_offensive['class']==0]['class']=1
# Out:
# C:\Users\Sunny\AppData\Local\Temp/ipykernel_26936/2275510384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_offensive[df_offensive['class']==0]['class']=1

# %%
df_offensive.head(5)
# Out:
#    class                                              tweet
# 0      2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df_offensive['class'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df_offensive[df_offensive['class']==0]
# Out:
#        class                                              tweet
# 85         0  "@Blackman38Tide: @WhaleLookyHere @HowdyDowdy1...
# 89         0  "@CB_Baby24: @white_thunduh alsarabsss" hes a ...
# 110        0  "@DevilGrimz: @VigxRArts you're fucking gay, b...
# 184        0  "@MarkRoundtreeJr: LMFAOOOO I HATE BLACK PEOPL...
# 202        0  "@NoChillPaz: "At least I'm not a nigger" http...
# ...      ...                                                ...
# 24576      0                this guy is the biggest faggot omfg
# 24685      0  which one of these names is more offensive kik...
# 24751      0         you a pussy ass nigga and I know it nigga.
# 24776      0                                 you're all niggers
# 24777      0  you're such a retard i hope you get type 2 dia...
#
# [1430 rows x 2 columns]

# %%
df_offensive["class"].replace({0: 1}, inplace=True)

# %%
df_offensive['class'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
sns.countplot('class',data=df_offensive)
# Out:
# C:\Users\Sunny\.conda\envs\hate\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df_offensive["class"].replace({2: 0}, inplace=True)

# %%
df_offensive[df_offensive['class']==0]
# Out:
#        class                                              tweet
# 0          0  !!! RT @mayasolovely: As a woman you shouldn't...
# 40         0    " momma said no pussy cats inside my doghouse "
# 63         0  "@Addicted2Guys: -SimplyAddictedToGuys http://...
# 66         0  "@AllAboutManFeet: http://t.co/3gzUpfuMev" woo...
# 67         0  "@Allyhaaaaa: Lemmie eat a Oreo &amp; do these...
# ...      ...                                                ...
# 24736      0  yaya ho.. cute avi tho RT @ViVaLa_Ari I had no...
# 24737      0  yea so about @N_tel 's new friend.. all my fri...
# 24767      0  you know what they say, the early bird gets th...
# 24779      0  you've gone and broke the wrong heart baby, an...
# 24782      0  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [4163 rows x 2 columns]

# %%
sns.countplot('class',data=df_offensive)
# Out:
# C:\Users\Sunny\.conda\envs\hate\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df_offensive.rename(columns ={'class':'label'}, inplace = True)

# %%
df_offensive
# Out:
#        label                                              tweet
# 0          0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1          1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2          1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3          1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4          1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...      ...                                                ...
# 24778      1  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779      0  you've gone and broke the wrong heart baby, an...
# 24780      1  young buck wanna eat!!.. dat nigguh like I ain...
# 24781      1              youu got wild bitches tellin you lies
# 24782      0  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 2 columns]

# %%
df_offensive.head()
# Out:
#    label                                              tweet
# 0      0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1      1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df_offensive.iloc[0]['tweet']
# Out:
# "!!! RT @mayasolovely: As a woman you shouldn't complain about cleaning up your house. &amp; as a man you should always take the trash out..."

# %%
df_offensive.iloc[5]['tweet']
# Out:
# '!!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just blows me..claim you so faithful and down for somebody but still fucking with hoes! &#128514;&#128514;&#128514;"'

# %%
frame=[df_twitter,df_offensive]
df = pd.concat(frame)

# %%
df
# Out:
#        label                                              tweet
# 0          0   @user when a father is dysfunctional and is s...
# 1          0  @user @user thanks for #lyft credit i can't us...
# 2          0                                bihday your majesty
# 3          0  #model   i love u take with u all the time in ...
# 4          0             factsguide: society now    #motivation
# ...      ...                                                ...
# 24778      1  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779      0  you've gone and broke the wrong heart baby, an...
# 24780      1  young buck wanna eat!!.. dat nigguh like I ain...
# 24781      1              youu got wild bitches tellin you lies
# 24782      0  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [56745 rows x 2 columns]

# %%
df.head()
# Out:
#    label                                              tweet
# 0      0   @user when a father is dysfunctional and is s...
# 1      0  @user @user thanks for #lyft credit i can't us...
# 2      0                                bihday your majesty
# 3      0  #model   i love u take with u all the time in ...
# 4      0             factsguide: society now    #motivation

# %%
sns.countplot('label',data=df)
# Out:
# C:\Users\Sunny\.conda\envs\hate\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
df.shape
# Out:
# (56745, 2)

# %%
import re
import nltk
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('english'))

# %%
def make_wordcloud(df):
    comment_words=""
    for val in df.tweet: 
        val = str(val).lower()

      
        comment_words += " ".join(val)+" "
    print(comment_words[0:100])
    wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,min_font_size = 10).generate(comment_words)
  
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)

    plt.show()

# %%
x=df['tweet']
y=df['label']

# %%
x
# Out:
# 0         @user when a father is dysfunctional and is s...
# 1        @user @user thanks for #lyft credit i can't us...
# 2                                      bihday your majesty
# 3        #model   i love u take with u all the time in ...
# 4                   factsguide: society now    #motivation
#                                ...
# 24778    you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779    you've gone and broke the wrong heart baby, an...
# 24780    young buck wanna eat!!.. dat nigguh like I ain...
# 24781                youu got wild bitches tellin you lies
# 24782    ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
# Name: tweet, Length: 56745, dtype: object

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 24778    1
# 24779    0
# 24780    1
# 24781    1
# 24782    0
# Name: label, Length: 56745, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)
print(len(x_train), len(y_train))
print(len(x_test), len(y_test))
# Out:
# 42558 42558
# 14187 14187

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english', ngram_range=(1,5))
x_train_vectorizer=count.fit_transform(x_train)

# %%
x_test_vectorizer=count.transform(x_test)
x_train_vectorizer
# Out:
# <42558x916923 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1334468 stored elements in Compressed Sparse Row format>

# %%
count.vocabulary_
# Out:
# {'picture': 594347,
#  'gallery': 307548,
#  'live': 471658,
#  'blackcavalier': 120942,
#  'caucasian': 152699,
#  'webcam': 872577,
#  'picture gallery': 594436,
#  'gallery live': 307551,
#  'live blackcavalier': 471718,
#  'blackcavalier caucasian': 120943,
#  'caucasian webcam': 152703,
#  'picture gallery live': 594437,
#  'gallery live blackcavalier': 307552,
#  'live blackcavalier caucasian': 471719,
#  'blackcavalier caucasian webcam': 120944,
#  'picture gallery live blackcavalier': 594438,
#  'gallery live blackcavalier caucasian': 307553,
#  'live blackcavalier caucasian webcam': 471720,
#  'picture gallery live blackcavalier caucasian': 594439,
#  'gallery live blackcavalier caucasian webcam': 307554,
#  'shoutout': 707314,
#  'everybody': 256834,
#  'follow': 287215,
#  'nicca': 549486,
#  'shoutout everybody': 707340,
#  'everybody follow': 256956,
#  'follow nicca': 287534,
#  'shoutout everybody follow': 707341,
#  'everybody follow nicca': 256957,
#  'shoutout everybody follow nicca': 707342,
#  'user': 820082,
#  'bet': 95011,
#  'seconds': 692050,
#  'goal': 321378,
#  'bottlers': 129109,
#  'user user': 842187,
#  'user bet': 822352,
#  'bet seconds': 95195,
#  'seconds goal': 692070,
#  'goal bottlers': 321384,
#  'user user bet': 842489,
#  'user bet seconds': 822362,
#  'bet seconds goal': 95196,
#  'seconds goal bottlers': 692071,
#  'user user bet seconds': 842492,
#  'user bet seconds goal': 822363,
#  'bet seconds goal bottlers': 95197,
#  'user user bet seconds goal': 842493,
#  'user bet seconds goal bottlers': 822364,
#  'tattoosleeves': 760999,
#  'gorilla': 331565,
#  'simulator': 710848,
#  'need': 541195,
#  'adapt': 40605,
#  'environment': 253520,
#  'tear': 763416,
#  'city': 166197,
#  'tattoosleeves gorilla': 761000,
#  'gorilla simulator': 331619,
#  'simulator need': 710853,
#  'need adapt': 541239,
#  'adapt environment': 40606,
#  'environment need': 253533,
#  'need tear': 542550,
#  'tear city': 763428,
#  'tattoosleeves gorilla simulator': 761001,
#  'gorilla simulator need': 331620,
#  'simulator need adapt': 710854,
#  'need adapt environment': 541240,
#  'adapt environment need': 40607,
#  'environment need tear': 253534,
#  'need tear city': 542551,
#  'tattoosleeves gorilla simulator need': 761002,
#  'gorilla simulator need adapt': 331621,
#  'simulator need adapt environment': 710855,
#  'need adapt environment need': 541241,
#  'adapt environment need tear': 40608,
#  'environment need tear city': 253535,
#  'tattoosleeves gorilla simulator need adapt': 761003,
#  'gorilla simulator need adapt environment': 331622,
#  'simulator need adapt environment need': 710856,
#  'need adapt environment need tear': 541242,
#  'adapt environment need tear city': 40609,
#  'boy': 130752,
#  'ryanbowersob': 677670,
#  'got': 331767,
#  'hoes': 374836,
#  'boy ryanbowersob': 131229,
#  'ryanbowersob got': 677671,
#  'got hoes': 333407,
#  'boy ryanbowersob got': 131230,
#  'ryanbowersob got hoes': 677672,
#  'boy ryanbowersob got hoes': 131231,
#  'hate': 357616,
#  'alive': 49543,
#  'hater': 359096,
#  'orlandounited': 575847,
#  'hate alive': 357637,
#  'alive hater': 49570,
#  'hater orlandounited': 359114,
#  'hate alive hater': 357638,
#  'alive hater orlandounited': 49571,
#  'hate alive hater orlandounited': 357639,
#  'book': 126945,
#  'enduring': 251557,
#  'conviction': 181791,
#  'fred': 292683,
#  'korematsu': 442056,
#  'amp': 53927,
#  'quest': 623311,
#  'justice': 428651,
#  'humanrights': 391217,
#  'htâ': 390216,
#  'book enduring': 127023,
#  'enduring conviction': 251558,
#  'conviction fred': 181792,
#  'fred korematsu': 292688,
#  'korematsu amp': 442057,
#  'amp quest': 57710,
#  'quest justice': 623314,
#  'justice humanrights': 428669,
#  'humanrights htâ': 391226,
#  'book enduring conviction': 127024,
#  'enduring conviction fred': 251559,
#  'conviction fred korematsu': 181793,
#  'fred korematsu amp': 292689,
#  'korematsu amp quest': 442058,
#  'amp quest justice': 57711,
#  'quest justice humanrights': 623315,
#  'justice humanrights htâ': 428670,
#  'book enduring conviction fred': 127025,
#  'enduring conviction fred korematsu': 251560,
#  'conviction fred korematsu amp': 181794,
#  'fred korematsu amp quest': 292690,
#  'korematsu amp quest justice': 442059,
#  'amp quest justice humanrights': 57712,
#  'quest justice humanrights htâ': 623316,
#  'book enduring conviction fred korematsu': 127026,
#  'enduring conviction fred korematsu amp': 251561,
#  'conviction fred korematsu amp quest': 181795,
#  'fred korematsu amp quest justice': 292691,
#  'korematsu amp quest justice humanrights': 442060,
#  'amp quest justice humanrights htâ': 57713,
#  'reason': 635353,
#  'gun': 344408,
#  'lobby': 476382,
#  'senate': 695295,
#  'pay': 583936,
#  'senators': 695337,
#  'rep': 641836,
#  'dem': 213982,
#  'make': 498426,
#  'sure': 752206,
#  'continue': 181100,
#  'making': 501579,
#  'billions': 101166,
#  'guns': 344772,
#  'industry': 402400,
#  'user reason': 837142,
#  'reason gun': 635485,
#  'gun lobby': 344523,
#  'lobby senate': 476400,
#  'senate pay': 695306,
#  'pay senators': 584424,
#  'senators rep': 695342,
#  'rep dem': 641837,
#  'dem make': 214125,
#  'make sure': 500107,
#  'sure continue': 752285,
#  'continue making': 181129,
#  'making billions': 501641,
#  'billions guns': 101167,
#  'guns industry': 344856,
#  'user reason gun': 837149,
#  'reason gun lobby': 635486,
#  'gun lobby senate': 344527,
#  'lobby senate pay': 476401,
#  'senate pay senators': 695307,
#  'pay senators rep': 584425,
#  'senators rep dem': 695343,
#  'rep dem make': 641838,
#  'dem make sure': 214126,
#  'make sure continue': 500125,
#  'sure continue making': 752286,
#  'continue making billions': 181130,
#  'making billions guns': 501642,
#  'billions guns industry': 101168,
#  'user reason gun lobby': 837150,
#  'reason gun lobby senate': 635487,
#  'gun lobby senate pay': 344528,
#  'lobby senate pay senators': 476402,
#  'senate pay senators rep': 695308,
#  'pay senators rep dem': 584426,
#  'senators rep dem make': 695344,
#  'rep dem make sure': 641839,
#  'dem make sure continue': 214127,
#  'make sure continue making': 500126,
#  'sure continue making billions': 752287,
#  'continue making billions guns': 181131,
#  'making billions guns industry': 501643,
#  'user reason gun lobby senate': 837151,
#  'reason gun lobby senate pay': 635488,
#  'gun lobby senate pay senators': 344529,
#  'lobby senate pay senators rep': 476403,
#  'senate pay senators rep dem': 695309,
#  'pay senators rep dem make': 584427,
#  'senators rep dem make sure': 695345,
#  'rep dem make sure continue': 641840,
#  'dem make sure continue making': 214128,
#  'make sure continue making billions': 500127,
#  'sure continue making billions guns': 752288,
#  'continue making billions guns industry': 181132,
#  'dinner': 222420,
#  'friend': 295625,
#  'steak': 736813,
#  'shop': 706138,
#  'disappoint': 223484,
#  'yummy': 912157,
#  'nice': 550018,
#  'evening': 256361,
#  'theâ': 773950,
#  'dinner friend': 222485,
#  'friend steak': 296058,
#  'steak shop': 736862,
#  'shop disappoint': 706158,
#  'disappoint yummy': 223500,
#  'yummy nice': 912222,
#  'nice evening': 550190,
#  'evening theâ': 256479,
#  'dinner friend steak': 222486,
#  'friend steak shop': 296059,
#  'steak shop disappoint': 736863,
#  'shop disappoint yummy': 706159,
#  'disappoint yummy nice': 223501,
#  'yummy nice evening': 912223,
#  'nice evening theâ': 550191,
#  'dinner friend steak shop': 222487,
#  'friend steak shop disappoint': 296060,
#  'steak shop disappoint yummy': 736864,
#  'shop disappoint yummy nice': 706160,
#  'disappoint yummy nice evening': 223502,
#  'yummy nice evening theâ': 912224,
#  'dinner friend steak shop disappoint': 222488,
#  'friend steak shop disappoint yummy': 296061,
#  'steak shop disappoint yummy nice': 736865,
#  'shop disappoint yummy nice evening': 706161,
#  'disappoint yummy nice evening theâ': 223503,
#  'buy': 143178,
#  'records': 636675,
#  'mainly': 498168,
#  'rap': 628278,
#  'albums': 48693,
#  'discogs': 223723,
#  'hiphop': 370196,
#  'lps': 493351,
#  'forsale': 291061,
#  'music': 534512,
#  'love': 485850,
#  'ebay': 246070,
#  'buy records': 143472,
#  'records mainly': 636694,
#  'mainly rap': 498170,
#  'rap albums': 628282,
#  'albums discogs': 48702,
#  'discogs rap': 223724,
#  'rap hiphop': 628322,
#  'hiphop lps': 370216,
#  'lps records': 493352,
#  'records forsale': 636686,
#  'forsale music': 291062,
#  'music love': 534843,
#  'love ebay': 487025,
#  'buy records mainly': 143473,
#  'records mainly rap': 636695,
#  'mainly rap albums': 498171,
#  'rap albums discogs': 628283,
#  'albums discogs rap': 48703,
#  'discogs rap hiphop': 223725,
#  'rap hiphop lps': 628323,
#  'hiphop lps records': 370217,
#  'lps records forsale': 493353,
#  'records forsale music': 636687,
#  'forsale music love': 291063,
#  'music love ebay': 534850,
#  'buy records mainly rap': 143474,
#  'records mainly rap albums': 636696,
#  'mainly rap albums discogs': 498172,
#  'rap albums discogs rap': 628284,
#  'albums discogs rap hiphop': 48704,
#  'discogs rap hiphop lps': 223726,
#  'rap hiphop lps records': 628324,
#  'hiphop lps records forsale': 370218,
#  'lps records forsale music': 493354,
#  'records forsale music love': 636688,
#  'forsale music love ebay': 291064,
#  'buy records mainly rap albums': 143475,
#  'records mainly rap albums discogs': 636697,
#  'mainly rap albums discogs rap': 498173,
#  'rap albums discogs rap hiphop': 628285,
#  'albums discogs rap hiphop lps': 48705,
#  'discogs rap hiphop lps records': 223727,
#  'rap hiphop lps records forsale': 628325,
#  'hiphop lps records forsale music': 370219,
#  'lps records forsale music love': 493355,
#  'records forsale music love ebay': 636689,
#  'bossdog': 128794,
#  'bossdog user': 128795,
#  'bossdog user user': 128796,
#  'rt': 654372,
#  'dadonherself_': 198098,
#  'niggas': 554282,
#  'fuck': 298494,
#  'pretty': 610617,
#  'girl': 316324,
#  'head': 361685,
#  'right': 647704,
#  'ho': 371800,
#  'pair': 579686,
#  'good': 327552,
#  'panties': 580480,
#  '128514': 6517,
#  '9996': 33384,
#  '65039': 22922,
#  'rt dadonherself_': 659311,
#  'dadonherself_ niggas': 198099,
#  'niggas fuck': 554921,
#  'fuck pretty': 300261,
#  'pretty girl': 610837,
#  'girl head': 316957,
#  'head right': 361995,
#  'right ho': 648168,
#  'ho got': 371905,
#  'got pair': 334309,
#  'pair good': 579715,
#  'good panties': 329305,
#  'panties 128514': 580481,
#  '128514 9996': 7981,
#  '9996 65039': 33390,
#  'rt dadonherself_ niggas': 659312,
#  'dadonherself_ niggas fuck': 198100,
#  'niggas fuck pretty': 554936,
#  'fuck pretty girl': 300262,
#  'pretty girl head': 610838,
#  'girl head right': 316958,
#  'head right ho': 361996,
#  'right ho got': 648169,
#  'ho got pair': 371909,
#  'got pair good': 334310,
#  'pair good panties': 579716,
#  'good panties 128514': 329306,
#  'panties 128514 9996': 580482,
#  '128514 9996 65039': 7982,
#  'rt dadonherself_ niggas fuck': 659313,
#  'dadonherself_ niggas fuck pretty': 198101,
#  'niggas fuck pretty girl': 554937,
#  'fuck pretty girl head': 300263,
#  'pretty girl head right': 610839,
#  'girl head right ho': 316959,
#  'head right ho got': 361997,
#  'right ho got pair': 648170,
#  'ho got pair good': 371910,
#  'got pair good panties': 334311,
#  'pair good panties 128514': 579717,
#  'good panties 128514 9996': 329307,
#  'panties 128514 9996 65039': 580483,
#  'rt dadonherself_ niggas fuck pretty': 659314,
#  'dadonherself_ niggas fuck pretty girl': 198102,
#  'niggas fuck pretty girl head': 554938,
#  'fuck pretty girl head right': 300264,
#  'pretty girl head right ho': 610840,
#  'girl head right ho got': 316960,
#  'head right ho got pair': 361998,
#  'right ho got pair good': 648171,
#  'ho got pair good panties': 371911,
#  'got pair good panties 128514': 334312,
#  'pair good panties 128514 9996': 579718,
#  'good panties 128514 9996 65039': 329308,
#  'yeeeaaahhh': 905799,
#  'wattpad': 869294,
#  'yeeeaaahhh wattpad': 905800,
#  'kelseyyvirginia': 431404,
#  'caylanashlee': 153973,
#  'look': 480206,
#  'bitch': 103371,
#  'wanted': 865158,
#  'gramatically': 337688,
#  'correct': 183739,
#  'kelseyyvirginia caylanashlee': 431405,
#  'caylanashlee look': 153978,
#  'look bitch': 480353,
#  'bitch wanted': 113733,
#  'wanted gramatically': 865267,
#  'gramatically correct': 337689,
#  'kelseyyvirginia caylanashlee look': 431406,
#  'caylanashlee look bitch': 153979,
#  'look bitch wanted': 480375,
#  'bitch wanted gramatically': 113737,
#  'wanted gramatically correct': 865268,
#  'kelseyyvirginia caylanashlee look bitch': 431407,
#  'caylanashlee look bitch wanted': 153980,
#  'look bitch wanted gramatically': 480376,
#  'bitch wanted gramatically correct': 113738,
#  'kelseyyvirginia caylanashlee look bitch wanted': 431408,
#  'caylanashlee look bitch wanted gramatically': 153981,
#  'look bitch wanted gramatically correct': 480377,
#  'gabrielleheaton': 307222,
#  '128064': 3985,
#  'rt gabrielleheaton': 661496,
#  'gabrielleheaton hoes': 307223,
#  'hoes 128064': 374856,
#  'rt gabrielleheaton hoes': 661497,
#  'gabrielleheaton hoes 128064': 307224,
#  'rt gabrielleheaton hoes 128064': 661498,
#  'gotta': 335675,
#  'remind': 641217,
#  'da': 196143,
#  'phone': 591927,
#  'cuz': 195192,
#  'sidetracked': 709422,
#  'bad': 79519,
#  'bitches': 114420,
#  'den': 214666,
#  'mad': 496536,
#  'meet': 512123,
#  'em': 249077,
#  'gotta remind': 336266,
#  'remind da': 641243,
#  'da phone': 196622,
#  'phone cuz': 592034,
#  'cuz sidetracked': 195603,
#  'sidetracked bad': 709423,
#  'bad bitches': 79883,
#  'bitches den': 115580,
#  'den mad': 214705,
#  'mad cuz': 496677,
#  'cuz meet': 195498,
#  'meet em': 512196,
#  'gotta remind da': 336270,
#  'remind da phone': 641244,
#  'da phone cuz': 196623,
#  'phone cuz sidetracked': 592042,
#  'cuz sidetracked bad': 195604,
#  'sidetracked bad bitches': 709424,
#  'bad bitches den': 79928,
#  'bitches den mad': 115581,
#  'den mad cuz': 214706,
#  'mad cuz meet': 496690,
#  'cuz meet em': 195499,
#  'gotta remind da phone': 336271,
#  'remind da phone cuz': 641245,
#  'da phone cuz sidetracked': 196624,
#  'phone cuz sidetracked bad': 592043,
#  'cuz sidetracked bad bitches': 195605,
#  'sidetracked bad bitches den': 709425,
#  'bad bitches den mad': 79929,
#  'bitches den mad cuz': 115582,
#  'den mad cuz meet': 214707,
#  'mad cuz meet em': 496691,
#  'gotta remind da phone cuz': 336272,
#  'remind da phone cuz sidetracked': 641246,
#  'da phone cuz sidetracked bad': 196625,
#  'phone cuz sidetracked bad bitches': 592044,
#  'cuz sidetracked bad bitches den': 195606,
#  'sidetracked bad bitches den mad': 709426,
#  'bad bitches den mad cuz': 79930,
#  'bitches den mad cuz meet': 115583,
#  'den mad cuz meet em': 214708,
#  'englandbailey': 252089,
#  'happy': 352391,
#  'birthday': 102949,
#  'nicest': 550675,
#  'faggot': 264057,
#  '128129': 5208,
#  'http': 386799,
#  'vzygni9qtq': 858419,
#  'rt englandbailey': 660628,
#  'englandbailey happy': 252090,
#  'happy birthday': 352901,
#  'birthday nicest': 103086,
#  'nicest faggot': 550676,
#  'faggot 128129': 264059,
#  '128129 http': 5278,
#  'http vzygni9qtq': 389509,
#  'rt englandbailey happy': 660629,
#  'englandbailey happy birthday': 252091,
#  'happy birthday nicest': 352975,
#  'birthday nicest faggot': 103087,
#  'nicest faggot 128129': 550677,
#  'faggot 128129 http': 264060,
#  '128129 http vzygni9qtq': 5279,
#  'rt englandbailey happy birthday': 660630,
#  'englandbailey happy birthday nicest': 252092,
#  'happy birthday nicest faggot': 352976,
#  'birthday nicest faggot 128129': 103088,
#  'nicest faggot 128129 http': 550678,
#  'faggot 128129 http vzygni9qtq': 264061,
#  'rt englandbailey happy birthday nicest': 660631,
#  'englandbailey happy birthday nicest faggot': 252093,
#  'happy birthday nicest faggot 128129': 352977,
#  'birthday nicest faggot 128129 http': 103089,
#  'nicest faggot 128129 http vzygni9qtq': 550679,
#  'theyloveblaq_': 773918,
#  'joseline': 419726,
#  'did': 219119,
#  'sneak': 720926,
#  'athea': 72601,
#  'dont': 234348,
#  'like': 459351,
#  'coming': 175879,
#  'sit': 712577,
#  'yo': 908157,
#  'ass': 69236,
#  'onnat': 571793,
#  'couch': 184342,
#  'thats': 770835,
#  '8230': 32013,
#  'rt theyloveblaq_': 673053,
#  'theyloveblaq_ joseline': 773919,
#  'joseline did': 419730,
#  'did sneak': 219835,
#  'sneak athea': 720927,
#  'athea bitch': 72602,
#  'bitch dont': 106563,
#  'dont like': 234661,
#  'like coming': 460981,
#  'coming like': 176102,
#  'like amp': 459749,
#  'amp sit': 58174,
#  'sit yo': 712756,
#  'yo ass': 908177,
#  'ass onnat': 71025,
#  'onnat couch': 571794,
#  'couch thats': 184363,
#  'thats 8230': 770840,
#  'rt theyloveblaq_ joseline': 673054,
#  'theyloveblaq_ joseline did': 773920,
#  'joseline did sneak': 419731,
#  'did sneak athea': 219836,
#  'sneak athea bitch': 720928,
#  'athea bitch dont': 72603,
#  'bitch dont like': 106580,
#  'dont like coming': 234666,
#  'like coming like': 460982,
#  'coming like amp': 176103,
#  'like amp sit': 459765,
#  'amp sit yo': 58179,
#  'sit yo ass': 712757,
#  'yo ass onnat': 908203,
#  'ass onnat couch': 71026,
#  'onnat couch thats': 571795,
#  'couch thats 8230': 184364,
#  'rt theyloveblaq_ joseline did': 673055,
#  'theyloveblaq_ joseline did sneak': 773921,
#  'joseline did sneak athea': 419732,
#  'did sneak athea bitch': 219837,
#  'sneak athea bitch dont': 720929,
#  'athea bitch dont like': 72604,
#  'bitch dont like coming': 106582,
#  'dont like coming like': 234667,
#  'like coming like amp': 460983,
#  'coming like amp sit': 176104,
#  'like amp sit yo': 459766,
#  'amp sit yo ass': 58180,
#  'sit yo ass onnat': 712758,
#  'yo ass onnat couch': 908204,
#  'ass onnat couch thats': 71027,
#  'onnat couch thats 8230': 571796,
#  'rt theyloveblaq_ joseline did sneak': 673056,
#  'theyloveblaq_ joseline did sneak athea': 773922,
#  'joseline did sneak athea bitch': 419733,
#  'did sneak athea bitch dont': 219838,
#  'sneak athea bitch dont like': 720930,
#  'athea bitch dont like coming': 72605,
#  'bitch dont like coming like': 106583,
#  'dont like coming like amp': 234668,
#  'like coming like amp sit': 460984,
#  'coming like amp sit yo': 176105,
#  'like amp sit yo ass': 459767,
#  'amp sit yo ass onnat': 58181,
#  'sit yo ass onnat couch': 712759,
#  'yo ass onnat couch thats': 908205,
#  'ass onnat couch thats 8230': 71028,
#  'movie': 531649,
#  'ain': 45086,
#  'star': 733992,
#  'stars': 734450,
#  'extras': 261183,
#  '171': 14217,
#  'chantegooden': 157462,
#  'pride': 611592,
#  'chick': 161065,
#  '187': 14546,
#  'movie everybody': 531728,
#  'everybody ain': 256844,
#  'ain star': 46535,
#  'star need': 734098,
#  'need stars': 542418,
#  'stars extras': 734461,
#  'extras 171': 261184,
#  '171 chantegooden': 14229,
#  'chantegooden hate': 157463,
#  'hate hoes': 358259,
#  'hoes pride': 377402,
#  'pride chick': 611598,
#  'chick 187': 161066,
#  'movie everybody ain': 531729,
#  'everybody ain star': 256848,
#  'ain star need': 46536,
#  'star need stars': 734099,
#  'need stars extras': 542419,
#  'stars extras 171': 734462,
#  'extras 171 chantegooden': 261185,
#  '171 chantegooden hate': 14230,
#  'chantegooden hate hoes': 157464,
#  'hate hoes pride': 358271,
#  'hoes pride chick': 377403,
#  'pride chick 187': 611599,
#  'movie everybody ain star': 531730,
#  'everybody ain star need': 256849,
#  'ain star need stars': 46537,
#  'star need stars extras': 734100,
#  'need stars extras 171': 542420,
#  'stars extras 171 chantegooden': 734463,
#  'extras 171 chantegooden hate': 261186,
#  '171 chantegooden hate hoes': 14231,
#  'chantegooden hate hoes pride': 157465,
#  'hate hoes pride chick': 358272,
#  'hoes pride chick 187': 377404,
#  'movie everybody ain star need': 531731,
#  'everybody ain star need stars': 256850,
#  'ain star need stars extras': 46538,
#  'star need stars extras 171': 734101,
#  'need stars extras 171 chantegooden': 542421,
#  'stars extras 171 chantegooden hate': 734464,
#  'extras 171 chantegooden hate hoes': 261187,
#  '171 chantegooden hate hoes pride': 14232,
#  'chantegooden hate hoes pride chick': 157466,
#  'hate hoes pride chick 187': 358273,
#  'gottaluvlexci_': 336468,
#  '128557': 10866,
#  'myhips_dntlie': 536312,
#  'tight': 781996,
#  'pants': 580531,
#  'loud': 485581,
#  'colors': 173609,
#  'fag': 263821,
#  'rt gottaluvlexci_': 661785,
#  'gottaluvlexci_ 128557': 336469,
#  '128557 128557': 10984,
#  '128557 rt': 11349,
#  'rt myhips_dntlie': 667787,
#  'myhips_dntlie tight': 536313,
#  'tight pants': 782042,
#  'pants loud': 580577,
#  'loud colors': 485590,
#  'colors look': 173649,
#  'look like': 480894,
#  'like fag': 461731,
#  'fag 128557': 263826,
#  'rt gottaluvlexci_ 128557': 661786,
#  'gottaluvlexci_ 128557 128557': 336470,
#  '128557 128557 128557': 10999,
#  '128557 128557 rt': 11111,
#  '128557 rt myhips_dntlie': 11383,
#  'rt myhips_dntlie tight': 667788,
#  'myhips_dntlie tight pants': 536314,
#  'tight pants loud': 782043,
#  'pants loud colors': 580578,
#  'loud colors look': 485591,
#  'colors look like': 173650,
#  'look like fag': 481058,
#  'like fag 128557': 461732,
#  'rt gottaluvlexci_ 128557 128557': 661787,
#  'gottaluvlexci_ 128557 128557 128557': 336471,
#  '128557 128557 128557 128557': 11005,
#  '128557 128557 128557 rt': 11031,
#  '128557 128557 rt myhips_dntlie': 11128,
#  '128557 rt myhips_dntlie tight': 11384,
#  'rt myhips_dntlie tight pants': 667789,
#  'myhips_dntlie tight pants loud': 536315,
#  'tight pants loud colors': 782044,
#  'pants loud colors look': 580579,
#  'loud colors look like': 485592,
#  'colors look like fag': 173651,
#  'look like fag 128557': 481059,
#  'rt gottaluvlexci_ 128557 128557 128557': 661788,
#  'gottaluvlexci_ 128557 128557 128557 128557': 336472,
#  '128557 128557 128557 128557 128557': 11007,
#  '128557 128557 128557 128557 rt': 11011,
#  '128557 128557 128557 rt myhips_dntlie': 11036,
#  '128557 128557 rt myhips_dntlie tight': 11129,
#  '128557 rt myhips_dntlie tight pants': 11385,
#  'rt myhips_dntlie tight pants loud': 667790,
#  'myhips_dntlie tight pants loud colors': 536316,
#  'tight pants loud colors look': 782045,
#  'pants loud colors look like': 580580,
#  'loud colors look like fag': 485593,
#  'colors look like fag 128557': 173652,
#  'nochillpaz': 559357,
#  'says': 686860,
#  'broke': 136845,
#  'yfsl9rnk0j': 907970,
#  'rt nochillpaz': 668251,
#  'nochillpaz bitch': 559358,
#  'bitch says': 111750,
#  'says broke': 686916,
#  'broke http': 137001,
#  'http yfsl9rnk0j': 389775,
#  'rt nochillpaz bitch': 668252,
#  'nochillpaz bitch says': 559362,
#  'bitch says broke': 111751,
#  'says broke http': 686917,
#  'broke http yfsl9rnk0j': 137002,
#  'rt nochillpaz bitch says': 668255,
#  'nochillpaz bitch says broke': 559363,
#  'bitch says broke http': 111752,
#  'says broke http yfsl9rnk0j': 686918,
#  'rt nochillpaz bitch says broke': 668256,
#  'nochillpaz bitch says broke http': 559364,
#  'bitch says broke http yfsl9rnk0j': 111753,
#  'aww': 76944,
#  'yeah': 903553,
#  'bing': 101351,
#  'bong': 126636,
#  'aww yeah': 76983,
#  'yeah good': 903798,
#  'good bing': 327704,
#  'bing bong': 101352,
#  'bong bing': 126637,
#  'aww yeah good': 76984,
#  'yeah good bing': 903799,
#  'good bing bong': 327705,
#  'bing bong bing': 101353,
#  'bong bing bong': 126638,
#  'aww yeah good bing': 76985,
#  'yeah good bing bong': 903800,
#  'good bing bong bing': 327706,
#  'bing bong bing bong': 101354,
#  'aww yeah good bing bong': 76986,
#  'yeah good bing bong bing': 903801,
#  'good bing bong bing bong': 327707,
#  'don': 229917,
#  'count': 184806,
#  'days': 208304,
#  'spring': 731179,
#  'memories': 513429,
#  'flowers': 285744,
#  'vine': 855140,
#  'don count': 230542,
#  'count days': 184847,
#  'days make': 208919,
#  'make days': 498829,
#  'days count': 208514,
#  'count spring': 184921,
#  'spring memories': 731209,
#  'memories flowers': 513451,
#  'flowers vine': 285939,
#  'vine user': 855214,
#  'don count days': 230543,
#  'count days make': 184848,
#  'days make days': 208923,
#  'make days count': 498830,
#  'days count spring': 208518,
#  'count spring memories': 184922,
#  'spring memories flowers': 731213,
#  'memories flowers vine': 513452,
#  'flowers vine user': 285940,
#  'don count days make': 230544,
#  'count days make days': 184851,
#  'days make days count': 208924,
#  'make days count spring': 498833,
#  'days count spring memories': 208519,
#  'count spring memories flowers': 184923,
#  'spring memories flowers vine': 731214,
#  'memories flowers vine user': 513453,
#  'don count days make days': 230546,
#  'count days make days count': 184852,
#  'days make days count spring': 208926,
#  'make days count spring memories': 498834,
#  'days count spring memories flowers': 208520,
#  'count spring memories flowers vine': 184924,
#  'spring memories flowers vine user': 731215,
#  'hates': 359165,
#  'white': 880078,
#  'crayon': 188039,
#  'looks': 482781,
#  'perfect': 589128,
#  'bleed': 121977,
#  'break': 133188,
#  'hates white': 359215,
#  'white crayon': 880317,
#  'crayon looks': 188043,
#  'looks perfect': 483180,
#  'perfect bleed': 589160,
#  'bleed break': 121981,
#  'hates white crayon': 359216,
#  'white crayon looks': 880321,
#  'crayon looks perfect': 188044,
#  'looks perfect bleed': 483181,
#  'perfect bleed break': 589161,
#  'hates white crayon looks': 359217,
#  'white crayon looks perfect': 880322,
#  'crayon looks perfect bleed': 188045,
#  'looks perfect bleed break': 483182,
#  'hates white crayon looks perfect': 359218,
#  'white crayon looks perfect bleed': 880323,
#  'crayon looks perfect bleed break': 188046,
#  'defending': 212628,
#  'ray': 629416,
#  'rice': 646506,
#  'double': 235949,
#  'standard': 733662,
#  'plkfb3lnem': 600506,
#  'defending ray': 212658,
#  'ray rice': 629431,
#  'rice double': 646535,
#  'double standard': 236048,
#  'standard bitch': 733672,
#  'bitch ain': 104073,
#  'ain http': 45910,
#  'http plkfb3lnem': 388839,
#  'defending ray rice': 212659,
#  'ray rice double': 629439,
#  'rice double standard': 646536,
#  'double standard bitch': 236049,
#  'standard bitch ain': 733673,
#  'bitch ain http': 104158,
#  'ain http plkfb3lnem': 45916,
#  'defending ray rice double': 212660,
#  'ray rice double standard': 629440,
#  'rice double standard bitch': 646537,
#  'double standard bitch ain': 236050,
#  'standard bitch ain http': 733674,
#  'bitch ain http plkfb3lnem': 104159,
#  'defending ray rice double standard': 212661,
#  'ray rice double standard bitch': 629441,
#  'rice double standard bitch ain': 646538,
#  'double standard bitch ain http': 236051,
#  'standard bitch ain http plkfb3lnem': 733675,
#  'michaeljace': 516594,
#  'actor': 39759,
#  'theshield': 773615,
#  'committed': 176914,
#  'horrific': 383937,
#  'act': 38921,
#  'god': 321701,
#  'help': 366167,
#  'family': 266539,
#  'terrible': 766325,
#  'legacy': 451156,
#  'michaeljace actor': 516595,
#  'actor theshield': 39843,
#  'theshield committed': 773616,
#  'committed horrific': 176935,
#  'horrific act': 383938,
#  'act god': 38961,
#  'god help': 322128,
#  'help family': 366281,
#  'family terrible': 267355,
#  'terrible legacy': 766346,
#  'michaeljace actor theshield': 516596,
#  'actor theshield committed': 39844,
#  'theshield committed horrific': 773617,
#  'committed horrific act': 176936,
#  'horrific act god': 383939,
#  'act god help': 38962,
#  'god help family': 322129,
#  'help family terrible': 366282,
#  'family terrible legacy': 267356,
#  'michaeljace actor theshield committed': 516597,
#  'actor theshield committed horrific': 39845,
#  'theshield committed horrific act': 773618,
#  'committed horrific act god': 176937,
#  'horrific act god help': 383940,
#  'act god help family': 38963,
#  'god help family terrible': 322130,
#  'help family terrible legacy': 366283,
#  'michaeljace actor theshield committed horrific': 516598,
#  'actor theshield committed horrific act': 39846,
#  'theshield committed horrific act god': 773619,
#  'committed horrific act god help': 176938,
#  'horrific act god help family': 383941,
#  'act god help family terrible': 38964,
#  'god help family terrible legacy': 322131,
#  'kids': 433357,
#  'fuck kids': 299834,
#  'kids bitch': 433424,
#  'fuck kids bitch': 299835,
#  'lookin': 481905,
#  'federalboobieinspector': 274314,
#  'wxlgv8xkdx': 898426,
#  'lookin hoes': 481974,
#  'hoes federalboobieinspector': 375987,
#  'federalboobieinspector http': 274315,
#  'http wxlgv8xkdx': 389614,
#  'lookin hoes federalboobieinspector': 481975,
#  'hoes federalboobieinspector http': 375988,
#  'federalboobieinspector http wxlgv8xkdx': 274316,
#  'lookin hoes federalboobieinspector http': 481976,
#  'hoes federalboobieinspector http wxlgv8xkdx': 375989,
#  'lookin hoes federalboobieinspector http wxlgv8xkdx': 481977,
#  'thankful': 769116,
#  'able': 36872,
#  'choose': 163912,
#  'positive': 605107,
#  'thankful able': 769117,
#  'able choose': 36903,
#  'choose thankful': 164071,
#  'thankful positive': 769566,
#  'thankful able choose': 769118,
#  'able choose thankful': 36904,
#  'choose thankful positive': 164072,
#  'thankful able choose thankful': 769119,
#  'able choose thankful positive': 36905,
#  'thankful able choose thankful positive': 769120,
#  'trash': 797354,
#  'bash': 84880,
#  '128540': 10098,
#  '127867': 3563,
#  'wxvvtem0fc': 898428,
#  'white trash': 880953,
#  'trash bash': 797556,
#  'bash 128540': 84881,
#  '128540 127867': 10099,
#  '127867 http': 3586,
#  'http wxvvtem0fc': 389616,
#  'white trash bash': 880957,
#  'trash bash 128540': 797557,
#  'bash 128540 127867': 84882,
#  '128540 127867 http': 10100,
#  '127867 http wxvvtem0fc': 3587,
#  'white trash bash 128540': 880958,
#  'trash bash 128540 127867': 797558,
#  'bash 128540 127867 http': 84883,
#  '128540 127867 http wxvvtem0fc': 10101,
#  'white trash bash 128540 127867': 880959,
#  'trash bash 128540 127867 http': 797559,
#  'bash 128540 127867 http wxvvtem0fc': 84884,
#  'cool': 182212,
#  'yaar': 900878,
#  'cool yaar': 182643,
#  'sick': 708967,
#  'pre': 608810,
#  'programmed': 613897,
#  'hillbots': 370009,
#  'rhetoric': 646308,
#  'unity': 815902,
#  'patriotism': 583535,
#  'feâ': 278484,
#  'user sick': 838656,
#  'sick pre': 709159,
#  'pre programmed': 608908,
#  'programmed hillbots': 613898,
#  'hillbots rhetoric': 370010,
#  'rhetoric unity': 646324,
#  'unity patriotism': 815918,
#  'patriotism love': 583536,
#  'love feâ': 487281,
#  'user sick pre': 838663,
#  'sick pre programmed': 709160,
#  'pre programmed hillbots': 608909,
#  'programmed hillbots rhetoric': 613899,
#  'hillbots rhetoric unity': 370011,
#  'rhetoric unity patriotism': 646325,
#  'unity patriotism love': 815919,
#  'patriotism love feâ': 583537,
#  'user sick pre programmed': 838664,
#  'sick pre programmed hillbots': 709161,
#  'pre programmed hillbots rhetoric': 608910,
#  'programmed hillbots rhetoric unity': 613900,
#  'hillbots rhetoric unity patriotism': 370012,
#  'rhetoric unity patriotism love': 646326,
#  'unity patriotism love feâ': 815920,
#  'user sick pre programmed hillbots': 838665,
#  'sick pre programmed hillbots rhetoric': 709162,
#  'pre programmed hillbots rhetoric unity': 608911,
#  'programmed hillbots rhetoric unity patriotism': 613901,
#  'hillbots rhetoric unity patriotism love': 370013,
#  'rhetoric unity patriotism love feâ': 646327,
#  'ascanioenteainment': 67685,
#  'redesigned': 637399,
#  'aquila': 65563,
#  'plains': 597466,
#  'screenshot': 690340,
#  'indiegameâ': 402197,
#  'ascanioenteainment redesigned': 67686,
#  'redesigned aquila': 637400,
#  'aquila plains': 65564,
#  'plains screenshot': 597467,
#  'screenshot indiegameâ': 690346,
#  'ascanioenteainment redesigned aquila': 67687,
#  'redesigned aquila plains': 637401,
#  'aquila plains screenshot': 65565,
#  'plains screenshot indiegameâ': 597468,
#  'ascanioenteainment redesigned aquila plains': 67688,
#  'redesigned aquila plains screenshot': 637402,
#  'aquila plains screenshot indiegameâ': 65566,
#  'ascanioenteainment redesigned aquila plains screenshot': 67689,
#  'redesigned aquila plains screenshot indiegameâ': 637403,
#  'carl': 150329,
#  ...}

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf = TfidfTransformer()

x_train_tfidf = tfidf.fit_transform(x_train_vectorizer)


x_test_tfidf = tfidf.transform(x_test_vectorizer)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
model_vectorizer= MultinomialNB().fit(x_train_vectorizer, y_train)
prediction_vectorizer=model_vectorizer.predict(x_test_vectorizer)
print(confusion_matrix(y_test,prediction_vectorizer))
print (classification_report(y_test, prediction_vectorizer))
# Out:
# [[7899  554]
#  [ 436 5298]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      8453
#            1       0.91      0.92      0.91      5734
#
#     accuracy                           0.93     14187
#    macro avg       0.93      0.93      0.93     14187
# weighted avg       0.93      0.93      0.93     14187

# %%
model_tfidf= MultinomialNB().fit(x_train_tfidf, y_train)
prediction_tfidf=model_tfidf.predict(x_test_tfidf)
print (classification_report(y_test, prediction_tfidf))
print(confusion_matrix(y_test,prediction_tfidf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      8453
#            1       0.95      0.86      0.90      5734
#
#     accuracy                           0.92     14187
#    macro avg       0.93      0.91      0.92     14187
# weighted avg       0.93      0.92      0.92     14187
#
# [[8184  269]
#  [ 798 4936]]

# %%
import xgboost as xgb
xgb_model=xgb.XGBClassifier(
        learning_rate=0.1,
        max_depth=7,
        n_estimators=80,
        use_label_encoder=False,
        eval_metric='auc' )

# %%
xgb_model_vectorizer = xgb_model.fit(x_train_vectorizer, y_train)
xgb_predictions_vectorizer=xgb_model_vectorizer.predict(x_test_vectorizer)
print(confusion_matrix(y_test,xgb_predictions_vectorizer))
print (classification_report(y_test, xgb_predictions_vectorizer))
# Out:
# [[8387   66]
#  [ 925 4809]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      8453
#            1       0.99      0.84      0.91      5734
#
#     accuracy                           0.93     14187
#    macro avg       0.94      0.92      0.93     14187
# weighted avg       0.94      0.93      0.93     14187

# %%
xgb_model = xgb_model.fit(x_train_tfidf, y_train)
xgb_predictions=xgb_model.predict(x_test_tfidf)
print(confusion_matrix(y_test,xgb_predictions))
print (classification_report(y_test, xgb_predictions))
# Out:
# [[8375   78]
#  [ 948 4786]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      8453
#            1       0.98      0.83      0.90      5734
#
#     accuracy                           0.93     14187
#    macro avg       0.94      0.91      0.92     14187
# weighted avg       0.93      0.93      0.93     14187

# %%
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding,SpatialDropout1D
from tensorflow.keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.models import Sequential

# %%
max_words = 50000
max_len = 300
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(x_train)
sequences = tokenizer.texts_to_sequences(x_train)
sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(max_words, 100, input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy',optimizer=RMSprop(),metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 100)          5000000
#
#  spatial_dropout1d (SpatialD  (None, 300, 100)         0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 100)               80400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 5,080,501
# Trainable params: 5,080,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping,ModelCheckpoint

stop = EarlyStopping(
    monitor='val_accuracy', 
    mode='max',
    patience=5
)

checkpoint= ModelCheckpoint(
    filepath='./',
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
history=model.fit(sequences_matrix,y_train,batch_size=1024,epochs=10,
          validation_split=0.2,callbacks=[stop,checkpoint])
# Out:
# Epoch 1/10
# 34/34 [==============================] - 40s 1s/step - loss: 0.5104 - accuracy: 0.7606 - val_loss: 0.3030 - val_accuracy: 0.8949
# Epoch 2/10
# 34/34 [==============================] - 36s 1s/step - loss: 0.2528 - accuracy: 0.9124 - val_loss: 0.2149 - val_accuracy: 0.9250
# Epoch 3/10
# 34/34 [==============================] - 35s 1s/step - loss: 0.1502 - accuracy: 0.9480 - val_loss: 0.1649 - val_accuracy: 0.9430
# Epoch 4/10
# 34/34 [==============================] - 34s 999ms/step - loss: 0.1076 - accuracy: 0.9638 - val_loss: 0.1888 - val_accuracy: 0.9429
# Epoch 5/10
# 34/34 [==============================] - 35s 1s/step - loss: 0.0848 - accuracy: 0.9716 - val_loss: 0.1965 - val_accuracy: 0.9219
# Epoch 6/10
# 34/34 [==============================] - 34s 989ms/step - loss: 0.0687 - accuracy: 0.9769 - val_loss: 0.1618 - val_accuracy: 0.9411
# Epoch 7/10
# 34/34 [==============================] - 34s 1s/step - loss: 0.0569 - accuracy: 0.9818 - val_loss: 0.1698 - val_accuracy: 0.9484
# Epoch 8/10
# 34/34 [==============================] - 34s 986ms/step - loss: 0.0484 - accuracy: 0.9855 - val_loss: 0.1724 - val_accuracy: 0.9437
# Epoch 9/10
# 34/34 [==============================] - 37s 1s/step - loss: 0.0419 - accuracy: 0.9875 - val_loss: 0.1787 - val_accuracy: 0.9445
# Epoch 10/10
# 34/34 [==============================] - 37s 1s/step - loss: 0.0341 - accuracy: 0.9896 - val_loss: 0.2017 - val_accuracy: 0.9433

# %%
test_sequences = tokenizer.texts_to_sequences(x_test)
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

# %%
accr = model.evaluate(test_sequences_matrix,y_test)
# Out:
# 444/444 [==============================] - 48s 108ms/step - loss: 0.2197 - accuracy: 0.9371

# %%
lstm_prediction=model.predict(test_sequences_matrix)

# %%
res=[]
for prediction in lstm_prediction:
    if prediction[0]<0.5:
        res.append(0)
    else:
        res.append(1)

# %%
print(confusion_matrix(y_test,res))
# Out:
# [[7995  458]
#  [ 434 5300]]

# %%
import pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
model.save("hate&abusive_model.h5")

# %%
import keras
load_model=keras.models.load_model("hate&abusive_model.h5")
with open('tokenizer.pickle', 'rb') as handle:
    load_tokenizer = pickle.load(handle)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
test = 'i will love you'
def clean_text(text):
    print(text)
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    print(text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
test=[clean_text(test)]
print(test)
seq = load_tokenizer.texts_to_sequences(test)
padded = sequence.pad_sequences(seq, maxlen=300)
print(seq)
pred = load_model.predict(padded)
print("pred", pred)
if pred<0.2:
    print("no hate")
else:
    print("hate and abusive")
# Out:
# i will love you
# i will love you
# ['love']
# [[24]]
# pred [[0.06192058]]
# no hate
